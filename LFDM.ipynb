# %% [markdown]
# <a href="https://colab.research.google.com/github/ronie-1989/Image_to_Video/blob/main/LFDM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/nihaomiao/CVPR23_LFDM.git
# Out:
# Cloning into 'CVPR23_LFDM'...
# remote: Enumerating objects: 266, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 266 (delta 29), reused 20 (delta 19), pack-reused 231
# Receiving objects: 100% (266/266), 27.03 MiB | 19.18 MiB/s, done.
# Resolving deltas: 100% (136/136), done.

# %%
# !git clone https://github.com/yalesong/natops.git
# Out:
# Cloning into 'natops'...
# remote: Enumerating objects: 38, done.
# remote: Total 38 (delta 0), reused 0 (delta 0), pack-reused 38
# Receiving objects: 100% (38/38), 1.06 MiB | 2.62 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
# !cd ..

# %%
# %cd natops/
# Out:
# /content/CVPR23_LFDM/natops

# %%
# !./download_natops.sh
# Out:
# --2024-07-17 14:20:53--  http://groups.csail.mit.edu/mug/natops/archive//body_hand_pose_s20.zip
# Resolving groups.csail.mit.edu (groups.csail.mit.edu)... 128.52.131.233
# Connecting to groups.csail.mit.edu (groups.csail.mit.edu)|128.52.131.233|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://groups.csail.mit.edu/mug/natops/archive//body_hand_pose_s20.zip [following]
# --2024-07-17 14:20:53--  https://groups.csail.mit.edu/mug/natops/archive//body_hand_pose_s20.zip
# Connecting to groups.csail.mit.edu (groups.csail.mit.edu)|128.52.131.233|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61108255 (58M) [application/zip]
# Saving to: ‘/content/CVPR23_LFDM/natops/data/body_hand_pose_s20.zip’
#
# body_hand_pose_s20. 100%[===================>]  58.28M  15.3MB/s    in 3.9s
#
# 2024-07-17 14:20:57 (15.0 MB/s) - ‘/content/CVPR23_LFDM/natops/data/body_hand_pose_s20.zip’ saved [61108255/61108255]
#
# ...

# %%
# %ls
# Out:
# data/  download_natops.sh*  images/  README.md

# %%
# %cd ..
# Out:
# /content/CVPR23_LFDM

# %%
# %ls
# Out:
# architecture.png  demo/  examples/  LICENSE.txt  natops/         README.md  requirements.txt
# config/           DM/    LFAE/      misc.py      preprocessing/  RegionMM/  sync_batchnorm/

# %%
# !pip install json_tricks

# %%
# %cd preprocessing
# Out:
# /content/CVPR23_LFDM/preprocessing

# %%
# !ls
# Out:
# preprocess_MHAD.py  preprocess_MUG.py  preprocess_NATOPS.py

# %%
# !python preprocess_NATOPS.py
# Out:
# [1, 3, 8, 9, 12, 13, 15, 17, 19, 20]
# [2, 4, 5, 6, 7, 10, 11, 14, 16, 18]
# g01s01.avi
# 100% 20/20 [00:21<00:00,  1.09s/it]
# g01s02.avi
# 100% 20/20 [00:19<00:00,  1.05it/s]
# g01s03.avi
# 100% 20/20 [00:17<00:00,  1.12it/s]
# g01s04.avi
# 100% 20/20 [00:18<00:00,  1.08it/s]
# g01s05.avi
# 100% 20/20 [00:13<00:00,  1.51it/s]
# g01s06.avi
# 100% 20/20 [00:20<00:00,  1.02s/it]
# g01s07.avi
# 100% 20/20 [00:11<00:00,  1.68it/s]
# g01s08.avi
# 100% 20/20 [00:19<00:00,  1.04it/s]
# g01s09.avi
# 100% 20/20 [00:19<00:00,  1.04it/s]
# g01s10.avi
# 100% 20/20 [00:16<00:00,  1.19it/s]
# g01s11.avi
# 100% 20/20 [00:19<00:00,  1.00it/s]
# g01s12.avi
# 100% 20/20 [00:18<00:00,  1.06it/s]
# g01s13.avi
# 100% 20/20 [00:22<00:00,  1.11s/it]
# g01s14.avi
# 100% 20/20 [00:17<00:00,  1.13it/s]
# g01s15.avi
# 100% 20/20 [00:16<00:00,  1.23it/s]
# g01s16.avi
# 100% 20/20 [00:13<00:00,  1.50it/s]
# g01s17.avi
# 100% 20/20 [00:19<00:00,  1.05it/s]
# g01s18.avi
# 100% 20/20 [00:17<00:00,  1.17it/s]
# ...

# %%
# %cd ..
# Out:
# /content/CVPR23_LFDM

# %%
# %ls
# Out:
# architecture.png  demo/  examples/  LICENSE.txt  natops/         README.md  requirements.txt
# config/           DM/    LFAE/      misc.py      preprocessing/  RegionMM/  sync_batchnorm/

# %%
# !pwd
# Out:
# /content/CVPR23_LFDM

# %%
#!wget https://github.com/snap-research/articulated-animation/blob/db2c2135273f601a370e2b62754f9bb56cfd25d5/checkpoints/taichi256.pth

# %%
# !python -u LFAE/run_natops.py
# Out:
# postfix: -crop
# checkpoint: /content/taichi256.pth
# batch size: 50
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# use crop box: 10 239 30 290
# save ckpt freq: 192
# Training...
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...

# %%
# %pwd
# Out:
# '/content/CVPR23_LFDM'

# %%
#!sudo apt-get install git-lfs

# %%
#!git lfs install

# %%
#!git clone https://github.com/nihaomiao/CVPR23_LFDM.git

# %%
#!ls -latr

# %%
#%cd CVPR23_LFDM/

# %%
#import torch
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# !nvidia-smi
# Out:
# Wed Jul 17 15:57:32 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install flow-vis

# %%
# !python -u LFAE/test_flowautoenc_natops.py
# Out:
# CUDA is available!
# /content/natops/flowautoenc_video_natops
# -crop
# RESTORE_FROM: /content/CVPR23_LFDM/RegionMM/log-natops/natops128-crop/snapshots-crop/RegionMM_0050_S000960.pth
# /content/natops/flowautoenc_video_natops/flowae-res-crop/loss1000-crop.json
# /content/CVPR23_LFDM/config/natops128.yaml
# save video: False
# cuda
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# => loading checkpoint '/content/CVPR23_LFDM/RegionMM/log-natops/natops128-crop/snapshots-crop/RegionMM_0050_S000960.pth'
# => loaded checkpoint '/content/CVPR23_LFDM/RegionMM/log-natops/natops128-crop/snapshots-crop/RegionMM_0050_S000960.pth'
# use crop box: 10 239 30 290
# ...

# %%
# !ls -latr
# Out:
# total 844
# -rw-r--r--  1 root root      7 Jul 17 10:39 .gitignore
# -rw-r--r--  1 root root   7467 Jul 17 10:39 README.md
# -rw-r--r--  1 root root   1351 Jul 17 10:39 LICENSE.txt
# -rw-r--r--  1 root root 780762 Jul 17 10:39 architecture.png
# drwxr-xr-x  5 root root   4096 Jul 17 10:39 demo
# drwxr-xr-x  2 root root   4096 Jul 17 10:39 examples
# -rw-r--r--  1 root root   7895 Jul 17 10:39 misc.py
# drwxr-xr-x  2 root root   4096 Jul 17 10:39 sync_batchnorm
# -rw-r--r--  1 root root    371 Jul 17 10:39 requirements.txt
# drwxr-xr-x  8 root root   4096 Jul 17 10:39 .git
# drwxr-xr-x  1 root root   4096 Jul 17 13:03 ..
# drwxr-xr-x  3 root root   4096 Jul 17 13:43 RegionMM
# drwxr-xr-x  2 root root   4096 Jul 17 14:19 preprocessing
# drwxr-xr-x  5 root root   4096 Jul 17 14:20 natops
# drwxr-xr-x  2 root root   4096 Jul 17 15:29 config
# drwxr-xr-x  2 root root   4096 Jul 17 15:59 __pycache__
# drwxr-xr-x 13 root root   4096 Jul 17 15:59 .
# ...

# %%
#%env PYTHONPATH=/content/CVPR23_LFDM:$PYTHONPATH

# %%
#!python -u LFAE/test_flowautoenc_natops.py

# %%
# !ls -latr
# Out:
# total 140
# -rw-r--r--  1 root root  5728 Jul 16 16:25 mhad_dataset.py
# -rw-r--r--  1 root root     0 Jul 16 16:25 __init__.py
# -rw-r--r--  1 root root  8875 Jul 16 16:25 frames_dataset.py
# -rw-r--r--  1 root root 12532 Jul 16 16:25 augmentation.py
# -rw-r--r--  1 root root  5939 Jul 16 16:25 run_mug.py
# -rw-r--r--  1 root root  5805 Jul 16 16:25 run_mhad.py
# -rw-r--r--  1 root root  5519 Jul 16 16:25 natops_dataset.py
# -rw-r--r--  1 root root  5073 Jul 16 16:25 mug_dataset.py
# -rw-r--r--  1 root root  9524 Jul 16 16:25 test_flowautoenc_mug.py
# -rw-r--r--  1 root root  9523 Jul 16 16:25 test_flowautoenc_mhad.py
# drwxr-xr-x  3 root root  4096 Jul 16 16:32 sync_batchnorm
# -rw-r--r--  1 root root  7517 Jul 16 20:08 train.py
# -rw-r--r--  1 root root  5602 Jul 16 20:09 run_natops.py
# drwxr-xr-x  2 root root  4096 Jul 16 20:09 __pycache__
# drwxr-xr-x  3 root root  4096 Jul 16 23:21 modules
# drwxr-xr-x 12 root root  4096 Jul 17 00:44 ..
# ...

# %%
# !pwd
# Out:
# /content/CVPR23_LFDM

# %%
sys.path.append("/content/CVPR23_LFDM/LFAE/modules")

# %%
# !pip install rotary-embedding-torch
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
# !pip install -r /content/CVPR23_LFDM/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 13.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 47.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 72.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 MB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 68.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 71.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 49.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 60.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 11.5 MB/s eta 0:00:00
# ...

# %%
# !pip install sacremoses
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 8.7 MB/s eta 0:00:00
# ...

# %%
# !python -u DM/train_video_flow_diffusion_natops.py
# Out:
# /content/natops/videoflowdiff_natops
# update saved model every: 400
# save model every: 10
# save video every: 200
# sample video every: 800
# -j-of-lnc-upconv
# RESTORE_FROM
# num examples per epoch: 48
# max epoch: 5
# image size, num frames: 128 40
# epoch milestones: [2, 4]
# frame sampling: uniform
# only use flow loss: True
# null_cond_prob: 0.1
# use residual flow: False
# learn null cond: True
# use deconv: False
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# NO checkpoint found!
# use crop box: 10 239 30 290
# ...

# %%
# !python -u DM/test_video_flow_diffusion_natops.py
# Out:
# /content/natops/videoflowdiff_natops
# -j-of-lnc-upconv
# /content/CVPR23_LFDM/config/natops128.yaml
# AE_RESTORE_FROM: /content/CVPR23_LFDM/RegionMM/log-natops/natops128-crop/snapshots-crop/RegionMM_0050_S000960.pth
# RESTORE_FROM: /content/natops/videoflowdiff_natops/snapshots-j-of-lnc-upconv/flowdiff_0005_S000050.pth
# cond scale: 1.0
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# => loading checkpoint '/content/natops/videoflowdiff_natops/snapshots-j-of-lnc-upconv/flowdiff_0005_S000050.pth'
# => loaded checkpoint '/content/natops/videoflowdiff_natops/snapshots-j-of-lnc-upconv/flowdiff_0005_S000050.pth'
# use crop box: 10 239 30 290
# ...

# %%
#sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.10/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  './LFAE/modules']

# %%
# !echo $PATH
# !echo $PYTHONPATH
# !export PYTHONPATH=$(pwd):$PYTHONPATH;echo $PYTHONPATH

# %%
# import sys
# import os

# SCRIPT_DIR = os.path.dirname(os.path.abspath(__file__))
# sys.path.append(os.path.dirname(SCRIPT_DIR))

# %%
# !cp -r /content/CVPR23_LFDM /content/drive/MyDrive/LFDM_modified

# %%
# !zip -r natops_dataset.zip /content/natops
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/natops/split_img_data/g19s02p20/g19s02p20-0010-1280.png (deflated 0%)
#   adding: content/natops/split_img_data/g19s02p20/g19s02p20-0045-1315.png (deflated 0%)
#   adding: content/natops/split_img_data/g19s02p20/g19s02p20-0034-1304.png (deflated 0%)
#   adding: content/natops/split_img_data/g19s02p20/g19s02p20-0025-1295.png (deflated 0%)
#   adding: content/natops/split_img_data/g19s02p20/g19s02p20-0046-1316.png (deflated 0%)
#   adding: content/natops/split_img_data/g19s02p20/g19s02p20-0026-1296.png (deflated 0%)
#   adding: content/natops/split_img_data/g19s02p20/g19s02p20-0029-1299.png (deflated 0%)
#   adding: content/natops/split_img_data/g19s02p20/g19s02p20-0016-1286.png (deflated 0%)
#   adding: content/natops/split_img_data/g19s02p20/g19s02p20-0020-1290.png (deflated 0%)
#   adding: content/natops/split_img_data/g19s02p20/g19s02p20-0015-1285.png (deflated 0%)
# ...

# %%
from google.colab import files

# %%
# !cp -r /content/CVPR23_LFDM/natops_dataset.zip /content/drive/MyDrive/LFDM_modified/all_data
# Out:
# cp: error writing '/content/drive/MyDrive/LFDM_modified/all_data': No space left on device
